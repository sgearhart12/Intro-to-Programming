# %%
print("Problem 5")
five_a={0: four_b[0], 1: four_b[1], 2: four_b[2], 3: four_b[3], 4: four_b[4]}
print(five_a)
five_b=four_b.append(str(300))
print(four_b)
five_c=four_b.append(type(str(300)))
print(four_b)
five_d=four_b
five_d[5]=four_b[5][:2]
print(five_d)
five_e=four_b.append(type(five_d))
print(four_b)
five_f= [x for x in four_b if type(x)==int]
print(five_f)
five_g=five_f.append(type(five_f[0]))
print(five_f)
five_h=five_f.append(type(three_setA))
print(five_f)
